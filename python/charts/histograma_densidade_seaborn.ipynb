# %% [markdown]
# ## Histograma com densidade e seaborn

# %% [markdown]
# #### Importando bibliotecas

# %%
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Impotando dados

# %%
data = pd.read_csv('../../data/trees.csv')
data2 = pd.read_csv('../../data/chicken.csv')
data2.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %% [markdown]
# #### Histograma com 10 divisões (bins) e com gráfico de densidade

# %%
srn.distplot(data.Volume, bins=10, axlabel='Volume').set_title('Árvores')
# Out:
# Text(0.5, 1.0, 'Árvores')

# %% [markdown]
# #### Criando um novo dataframe agrupando o atributo 'feed'

# %%
grouping = data2.groupby(['feed'])['weight'].sum()
grouping
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %% [markdown]
# #### Novo dataframe somente para testar os filtros do pandas

# %%
test = data2.loc[data2['feed'] == 'horsebean']
test
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %% [markdown]
# #### Histograma considerando somento o valor de 'horsebean'

# %%
srn.distplot(data2.loc[data2['feed'] == 'horsebean'].weight, hist = False).set_title('Horsebean')
# Out:
# Text(0.5, 1.0, 'Horsebean')

# %% [markdown]
# #### Histograma considerando somente o valor 'casein'

# %%
srn.distplot(data2.loc[data2['feed'] == 'casein'].weight).set_title('Casein')
# Out:
# Text(0.5, 1.0, 'Casein')

# %% [markdown]
# #### Histograma considerando somente o valor 'meatmeal'

# %%
srn.distplot(data2.loc[data2['feed'] == 'meatmeal'].weight).set_title('Meatmeal')
# Out:
# Text(0.5, 1.0, 'Meatmeal')

# %% [markdown]
# #### Histograma considerando somente o valor de 'soybean'

# %%
srn.distplot(data2.loc[data2['feed'] == 'soybean'].weight).set_title('Soybean')
# Out:
# Text(0.5, 1.0, 'Soybean')

# %% [markdown]
# #### Histograma considerando somente o valor 'sunflower'

# %%
srn.distplot(data2.loc[data2['feed'] == 'sunflower'].weight).set_title('Sunflower')
# Out:
# Text(0.5, 1.0, 'Sunflower')

# %% [markdown]
# #### Histograma considerando somente o valor 'linseed'

# %%
srn.distplot(data2.loc[data2['feed'] == 'linseed'].weight).set_title('linseed')
# Out:
# Text(0.5, 1.0, 'linseed')

# %% [markdown]
# #### Impressão em gráfico 2 x 3

# %%
plt.figure()
plt.subplot(3,2,1)
srn.distplot(data2.loc[data2['feed'] == 'horsebean'].weight, hist=False).set_title('Horsebean')
plt.subplot(3,2,2)
srn.distplot(data2.loc[data2['feed'] == 'casein'].weight).set_title('Casein')
plt.subplot(3,2,3)
srn.distplot(data2.loc[data2['feed'] == 'linseed'].weight).set_title('Linsed')
plt.subplot(3,2,4)
srn.distplot(data2.loc[data2['feed'] == 'meatmeal'].weight).set_title('Meatmeal')
plt.subplot(3,2,5)
srn.distplot(data2.loc[data2['feed'] == 'soybean'].weight).set_title('Soybean')
plt.subplot(3,2,6)
srn.distplot(data2.loc[data2['feed'] == 'sunflower'].weight).set_title('Sunflower')
# ajusta o layout para não haver sobreposição
plt.tight_layout()
