# %% [markdown]
# ## Gráfico de dispersão
# ___

# %% [markdown]
# #### Importando bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Importando dados

# %%
data = pd.read_csv('../data/trees.csv')
data.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %% [markdown]
# #### Gráfico de dispersão considerando o volume e a dispersão

# %%
plt.scatter(
    data.Girth,
    data.Volume,
    color='blue',
    facecolors='none',
    marker='.'
)
plt.title('Árvores')
plt.xlabel('Volume')
plt.ylabel('Circunferência')
# Out:
# Text(0, 0.5, 'Circunferência')

# %% [markdown]
# #### Gráfico de linha considerando o volume e o atributo 'Girth'

# %%
plt.plot(data.Girth, data.Volume)
plt.title('Árvores')
plt.xlabel('Volume')
plt.ylabel('Circunferência')
# Out:
# Text(0, 0.5, 'Circunferência')

# %% [markdown]
# #### Gráfico de dispersão com 'afastamento' dos dados (jitter)
#     fit_reg -> Linha de tendência
#     jitter -> Não deixa dados sobrescrito

# %%
sns.regplot(
    y='Girth',
    x='Volume',
    data=data,
    x_jitter=0.3,
    fit_reg=False)
# Out:
# <AxesSubplot: xlabel='Volume', ylabel='Girth'>
